# %% [markdown]
# # ДЗ 1
#
# ## 1.2
# Изучите стоимости недвижимости

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
plt.hist(df['price'], bins = 100)
plt.title('Распределение домов по стоимости')
plt.xlabel('Стоимость дома, $')
plt.ylabel('Кол-во домов');

# %% [markdown]
# Подавлящее количество домов продаются по цене до 1 млн с мат. ожиданием ~0,5 млн. Количество домов стоимостью выше 2 млн пренебрежительно мало.

# %% [markdown]
# ## 1.3
#
# Изучите распределение квадратуры жилой площади

# %%
plt.hist(df['sqft_living'], bins = 100)
plt.title('Распределение домов по жилой площади')
plt.xlabel('Жилая площадь дома, кв. фут')
plt.ylabel('Кол-во домов');

# %% [markdown]
# Большинство домов имеют площадь от 500 до 4.000 кв. футов с мат. ожиданием ~1.700 кв. футов . Домов с площадью больше 6.000 кв. футов - единичные варианты.

# %% [markdown]
# ## 1.4
#
# Изучите распределение года постройки

# %%
plt.hist(df['yr_built'], bins = 10)
plt.title('Распределение домов по году постройки')
plt.xlabel('Год постройки дома')
plt.ylabel('Кол-во домов');

# %% [markdown]
# Большинство домов построены после 1940-х гг (послевоенный бум) - практически равное распределение по десятилетиям от 1950-х до 2000-х включительно с ~20% скачком в 2010-х.

# %% [markdown]
# # ДЗ 2
#
# ## 2.1
#
# Изучите распределение домов от наличия вида на набережную

# %%
plt.pie(df['waterfront'].value_counts(), labels = ['Нет', 'Есть'], autopct = '%1.2f%%')
plt.title('Распределение домов по наличию вида на набережную')
donut = plt.Circle((0, 0), 0.85, color = 'white')
p = plt.gcf()
p.gca().add_artist(donut);

# %% [markdown]
# Распределение домов от наличия вида на набережную, показало, что только 0.75 % домов имеют вид на набережную.

# %% [markdown]
# ## 2.2
#
# Изучите распределение этажей домов

# %%
plt.pie(df['floors'].value_counts(), labels = df['floors'].value_counts().index, autopct = '%1.1f%%')
plt.title('Распределение домов по количеству этажей')
donut = plt.Circle((0, 0), 0.8, color = 'white')
p = plt.gcf()
p.gca().add_artist(donut);

# %% [markdown]
# Практически половина домов - одноэтажные. Около 38% домов имеют 2 этажа, 8,8% - 1,5 (?) этажа. Менее 4% приходится на прочие варианты.

# %% [markdown]
# ## 2.3
#
# Изучите распределение состояния домов

# %%
plt.pie(df['condition'].value_counts(), labels = df['condition'].value_counts().index, autopct = '%1.1f%%')
plt.title('Распределение домов по их состоянию')
donut = plt.Circle((0, 0), 0.8, color = 'white')
p = plt.gcf()
p.gca().add_artist(donut);

# %% [markdown]
# Около 2/3 домов находятся в среднем состоянии. Чуть больше четверти - в хорошем, а ~8% - в отличном. Плохих и ужасных домов - менее 1%.

# %% [markdown]
# # ДЗ 3
#
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.

# %%
df.corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_30e92_row0_col0, #T_30e92_row1_col1, #T_30e92_row2_col2, #T_30e92_row3_col3, #T_30e92_row4_col4, #T_30e92_row5_col5, #T_30e92_row6_col6, #T_30e92_row7_col7, #T_30e92_row8_col8, #T_30e92_row9_col9, #T_30e92_row10_col10, #T_30e92_row11_col11, #T_30e92_row12_col12, #T_30e92_row13_col13, #T_30e92_row14_col14, #T_30e92_row15_col15, #T_30e92_row16_col16, #T_30e92_row17_col17, #T_30e92_row18_col18, #T_30e92_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col1, #T_30e92_row2_col7, #T_30e92_row9_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col2, #T_30e92_row5_col1, #T_30e92_row7_col5, #T_30e92_row8_col16, #T_30e92_row9_col14, #T_30e92_row14_col19 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col3, #T_30e92_row3_col9, #T_30e92_row4_col16, #T_30e92_row6_col16 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col4, #T_30e92_row2_col19, #T_30e92_row7_col19, #T_30e92_row11_col12, #T_30e92_row14_col16 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col5, #T_30e92_row6_col12, #T_30e92_row9_col6, #T_30e92_row9_col13, #T_30e92_row13_col9, #T_30e92_row13_col14, #T_30e92_row13_col16, #T_30e92_row15_col1, #T_30e92_row15_col2, #T_30e92_row15_col3, #T_30e92_row15_col4, #T_30e92_row15_col5, #T_30e92_row15_col10, #T_30e92_row15_col11, #T_30e92_row15_col17, #T_30e92_row15_col18, #T_30e92_row15_col19, #T_30e92_row17_col7, #T_30e92_row17_col8, #T_30e92_row17_col15, #T_30e92_row19_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col6, #T_30e92_row3_col14, #T_30e92_row7_col10, #T_30e92_row8_col13, #T_30e92_row12_col16, #T_30e92_row14_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col8, #T_30e92_row9_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col9, #T_30e92_row3_col8, #T_30e92_row7_col13, #T_30e92_row16_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_30e92_row0_col10, #T_30e92_row13_col5, #T_30e92_row15_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col11, #T_30e92_row1_col5, #T_30e92_row2_col14, #T_30e92_row10_col14, #T_30e92_row18_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col12, #T_30e92_row3_col5, #T_30e92_row8_col19, #T_30e92_row11_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col13, #T_30e92_row5_col15, #T_30e92_row7_col9, #T_30e92_row11_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_30e92_row0_col14, #T_30e92_row14_col1, #T_30e92_row14_col8, #T_30e92_row14_col10, #T_30e92_row18_col16 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col15, #T_30e92_row5_col11, #T_30e92_row17_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_30e92_row0_col16, #T_30e92_row3_col0, #T_30e92_row7_col2, #T_30e92_row9_col19, #T_30e92_row11_col16, #T_30e92_row17_col14, #T_30e92_row19_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col17, #T_30e92_row1_col17, #T_30e92_row12_col18 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_30e92_row0_col18, #T_30e92_row10_col5, #T_30e92_row14_col18 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_30e92_row0_col19, #T_30e92_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_30e92_row1_col0, #T_30e92_row9_col5, #T_30e92_row14_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_30e92_row1_col2, #T_30e92_row14_col15 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_30e92_row1_col3, #T_30e92_row18_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_30e92_row1_col4, #T_30e92_row3_col11, #T_30e92_row19_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_30e92_row1_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_30e92_row1_col7, #T_30e92_row6_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_30e92_row1_col8, #T_30e92_row2_col12, #T_30e92_row6_col17 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_30e92_row1_col9, #T_30e92_row9_col17 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_30e92_row1_col10, #T_30e92_row10_col3 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_30e92_row1_col11, #T_30e92_row10_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_30e92_row1_col12, #T_30e92_row2_col10 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_30e92_row1_col13, #T_30e92_row10_col8, #T_30e92_row17_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_30e92_row1_col14, #T_30e92_row2_col9, #T_30e92_row4_col19, #T_30e92_row7_col18, #T_30e92_row16_col12, #T_30e92_row18_col19 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_30e92_row1_col15, #T_30e92_row8_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_30e92_row1_col16, #T_30e92_row12_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_30e92_row1_col18 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_30e92_row1_col19, #T_30e92_row8_col2, #T_30e92_row11_col14, #T_30e92_row19_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_30e92_row2_col0, #T_30e92_row2_col16, #T_30e92_row14_col5, #T_30e92_row16_col2, #T_30e92_row18_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_30e92_row2_col1, #T_30e92_row8_col11, #T_30e92_row16_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_30e92_row2_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_30e92_row2_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_30e92_row2_col5, #T_30e92_row2_col8, #T_30e92_row9_col18 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_30e92_row2_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_30e92_row2_col11, #T_30e92_row6_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_30e92_row2_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_30e92_row2_col15, #T_30e92_row7_col11, #T_30e92_row7_col12, #T_30e92_row19_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_30e92_row2_col17, #T_30e92_row10_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_30e92_row2_col18 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_30e92_row3_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_30e92_row3_col2, #T_30e92_row11_col17 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_30e92_row3_col4, #T_30e92_row4_col3, #T_30e92_row11_col10 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_30e92_row3_col6 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_30e92_row3_col7, #T_30e92_row6_col8, #T_30e92_row9_col0, #T_30e92_row14_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_30e92_row3_col10, #T_30e92_row4_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_30e92_row3_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_30e92_row3_col13 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_30e92_row3_col15, #T_30e92_row4_col14, #T_30e92_row7_col6, #T_30e92_row10_col16, #T_30e92_row11_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_30e92_row3_col16, #T_30e92_row11_col9, #T_30e92_row14_col2, #T_30e92_row15_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_30e92_row3_col17 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_30e92_row3_col18 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_30e92_row3_col19, #T_30e92_row5_col6, #T_30e92_row16_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_30e92_row4_col0, #T_30e92_row6_col5, #T_30e92_row11_col0, #T_30e92_row11_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_30e92_row4_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_30e92_row4_col5, #T_30e92_row8_col14, #T_30e92_row12_col17, #T_30e92_row13_col2, #T_30e92_row15_col9, #T_30e92_row19_col15 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_30e92_row4_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_30e92_row4_col7, #T_30e92_row6_col0, #T_30e92_row13_col15, #T_30e92_row17_col0, #T_30e92_row19_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_30e92_row4_col8, #

# %% [markdown]
# Наибольшее влияние на стоимость дома оказывает (очевидным образом) объём жилой площади.

# %%
import seaborn as sns
sns.jointplot(x = df['price'], y = df['sqft_living']);

# %% [markdown]
# Как видно из графика, каждая последующая (условно говоря) тысяча долларов в стоимости долларов даёт практически экспоненциальный рост в жилой площади вплоть до ~5.000 кв. футов. После этого (одновременно со снижением количества лотов) зависимость становится более линейной.

# %%
data = df.groupby(['waterfront'])['price'].mean().reset_index()
plt.bar(data['waterfront'], data['price'])
plt.title('Средняя стоимость дома по категориям вида на набережную')
plt.xticks(ticks = [0, 1], labels = ['Нет', 'Есть'])
plt.xlabel('Наличие вида на набережную')
plt.ylabel('Средняя стоимость дома');

# %% [markdown]
# Дом с видом на набережную в среднем в 3 раза дороже дома без такового вида.

# %%
df.boxplot(by = 'grade', column = ['price'], grid = False)
plt.title('Распределение стоимости домов по категориям грейда')
plt.xlabel('Категория грейда')
plt.ylabel('Стоимость дома');

# %% [markdown]
# Ещё один параметр, влияющий на стоимость дома - его грейд: чем он выше - тем не только дороже дом, но и больше разброс цен. На низких грейдах разброса практически нет, а на высших грейдах разброс цен кратный.

# %%
data = df.groupby(['view'])['price'].mean().sort_index().reset_index()
plt.bar(data['view'], data['price'])
plt.title('Средняя стоимость дома по категориям вида из окна')
plt.xlabel('Категория вида из окна')
plt.ylabel('Средняя стоимость дома');

# %% [markdown]
# Дома со средними категориями вида (1-3) стоят сравнительно одинаково, а вот пограничные значения категорий вида (0 и 4) сильно влияют на стоимость дома.
